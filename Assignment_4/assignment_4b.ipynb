# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"

# The GPU id to use, usually either "0" or "1"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 75
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 16)   2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 16)   64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 16)   2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 16)   64          conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 16)   0           activation_39[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 16)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 16)   2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 16)   64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 16)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 16)   2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 16)   64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 16)   0           activation_41[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 16)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 16)   2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 16)   64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 16)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 16)   2320        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 16)   64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 16)   0           activation_43[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 16)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 32)   4640        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 32)   9248        activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 32)   544         activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 32)   0           conv2d_52[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 32)   9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 32)   9248        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 32)   0           activation_47[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 32)   9248        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 32)   9248        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 32)   128         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 32)   0           activation_49[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 64)     18496       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 64)     256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 64)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 64)     2112        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 64)     256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           conv2d_59[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 64)     36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 64)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 64)     36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 64)     256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 64)     0           activation_53[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 64)     36928       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8, 8, 64)     256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 64)     0           activation_55[0][0]
#                                                                  batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 64)     0           add_27[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 64)     0           activation_57[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 64)           0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           650         flatten_3[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 73ms/step - loss: 1.5857 - accuracy: 0.4871 - val_loss: 1.3410 - val_accuracy: 0.5890
# Epoch 2/75
# Learning rate:  0.001
#    2/1563 [..............................] - ETA: 1:50 - loss: 1.3973 - accuracy: 0.5469
# C:\Users\vivek\Anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks\callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 1563/1563 [==============================] - 106s 68ms/step - loss: 1.2014 - accuracy: 0.6321 - val_loss: 1.2364 - val_accuracy: 0.6383
# Epoch 3/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 1.0367 - accuracy: 0.6927 - val_loss: 1.1525 - val_accuracy: 0.6599
# Epoch 4/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.9398 - accuracy: 0.7289 - val_loss: 1.0081 - val_accuracy: 0.7095
# Epoch 5/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 109s 70ms/step - loss: 0.8695 - accuracy: 0.7561 - val_loss: 0.9572 - val_accuracy: 0.7263
# Epoch 6/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.8192 - accuracy: 0.7782 - val_loss: 0.9009 - val_accuracy: 0.7514
# Epoch 7/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.7840 - accuracy: 0.7893 - val_loss: 0.8938 - val_accuracy: 0.7671
# Epoch 8/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.7550 - accuracy: 0.7996 - val_loss: 1.1064 - val_accuracy: 0.6960
# Epoch 9/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.7268 - accuracy: 0.8093 - val_loss: 0.7823 - val_accuracy: 0.7922
# Epoch 10/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.7103 - accuracy: 0.8161 - val_loss: 0.7947 - val_accuracy: 0.8007
# Epoch 11/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6897 - accuracy: 0.8253 - val_loss: 0.8454 - val_accuracy: 0.7735
# Epoch 12/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6760 - accuracy: 0.8306 - val_loss: 0.8851 - val_accuracy: 0.7715
# Epoch 13/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6641 - accuracy: 0.8356 - val_loss: 1.4700 - val_accuracy: 0.6454
# Epoch 14/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6525 - accuracy: 0.8407 - val_loss: 0.8366 - val_accuracy: 0.7876
# Epoch 15/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6438 - accuracy: 0.8441 - val_loss: 1.0592 - val_accuracy: 0.7381
# Epoch 16/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6344 - accuracy: 0.8478 - val_loss: 0.8460 - val_accuracy: 0.7769
# Epoch 17/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6227 - accuracy: 0.8516 - val_loss: 0.8806 - val_accuracy: 0.7859
# Epoch 18/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.6133 - accuracy: 0.8566 - val_loss: 0.8510 - val_accuracy: 0.7835
# Epoch 19/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 108s 69ms/step - loss: 0.6125 - accuracy: 0.8570 - val_loss: 0.8060 - val_accuracy: 0.8079
# Epoch 20/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 69ms/step - loss: 0.6043 - accuracy: 0.8598 - val_loss: 0.8397 - val_accuracy: 0.7908
# Epoch 21/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5987 - accuracy: 0.8606 - val_loss: 0.7707 - val_accuracy: 0.8163
# Epoch 22/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5928 - accuracy: 0.8647 - val_loss: 0.9282 - val_accuracy: 0.7677
# Epoch 23/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5887 - accuracy: 0.8647 - val_loss: 0.7578 - val_accuracy: 0.8176
# Epoch 24/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5851 - accuracy: 0.8668 - val_loss: 0.8075 - val_accuracy: 0.7998
# Epoch 25/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5812 - accuracy: 0.8683 - val_loss: 0.6951 - val_accuracy: 0.8356
# Epoch 26/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5756 - accuracy: 0.8708 - val_loss: 0.7017 - val_accuracy: 0.8329
# Epoch 27/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5721 - accuracy: 0.8716 - val_loss: 0.7112 - val_accuracy: 0.8372
# Epoch 28/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 108s 69ms/step - loss: 0.5661 - accuracy: 0.8741 - val_loss: 0.7190 - val_accuracy: 0.8270
# Epoch 29/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5632 - accuracy: 0.8745 - val_loss: 0.9283 - val_accuracy: 0.7739
# Epoch 30/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5646 - accuracy: 0.8741 - val_loss: 0.6386 - val_accuracy: 0.8536
# Epoch 31/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5590 - accuracy: 0.8760 - val_loss: 0.7688 - val_accuracy: 0.8155
# Epoch 32/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5597 - accuracy: 0.8765 - val_loss: 0.8039 - val_accuracy: 0.8001
# Epoch 33/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5518 - accuracy: 0.8791 - val_loss: 0.7000 - val_accuracy: 0.8395
# Epoch 34/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5519 - accuracy: 0.8788 - val_loss: 0.7079 - val_accuracy: 0.8305
# Epoch 35/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5484 - accuracy: 0.8812 - val_loss: 0.6873 - val_accuracy: 0.8425
# Epoch 36/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5475 - accuracy: 0.8805 - val_loss: 0.6811 - val_accuracy: 0.8417
# Epoch 37/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5436 - accuracy: 0.8829 - val_loss: 0.8213 - val_accuracy: 0.8099
# Epoch 38/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5397 - accuracy: 0.8833 - val_loss: 0.6538 - val_accuracy: 0.8474
# Epoch 39/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5382 - accuracy: 0.8856 - val_loss: 0.6956 - val_accuracy: 0.8369
# Epoch 40/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5364 - accuracy: 0.8860 - val_loss: 0.7656 - val_accuracy: 0.8187
# Epoch 41/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5355 - accuracy: 0.8856 - val_loss: 0.6358 - val_accuracy: 0.8521
# Epoch 42/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5330 - accuracy: 0.8864 - val_loss: 0.6408 - val_accuracy: 0.8542
# Epoch 43/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5312 - accuracy: 0.8879 - val_loss: 0.8846 - val_accuracy: 0.7837
# Epoch 44/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5315 - accuracy: 0.8873 - val_loss: 0.6321 - val_accuracy: 0.8610
# Epoch 45/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5303 - accuracy: 0.8896 - val_loss: 0.6320 - val_accuracy: 0.8589
# Epoch 46/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5299 - accuracy: 0.8878 - val_loss: 0.6452 - val_accuracy: 0.8562
# Epoch 47/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5303 - accuracy: 0.8880 - val_loss: 0.8079 - val_accuracy: 0.8052
# Epoch 48/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5215 - accuracy: 0.8914 - val_loss: 0.9353 - val_accuracy: 0.7783
# Epoch 49/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5189 - accuracy: 0.8940 - val_loss: 0.8833 - val_accuracy: 0.8081
# Epoch 50/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5196 - accuracy: 0.8915 - val_loss: 0.6970 - val_accuracy: 0.8367
# Epoch 51/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5199 - accuracy: 0.8911 - val_loss: 0.7539 - val_accuracy: 0.8237
# Epoch 52/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5186 - accuracy: 0.8932 - val_loss: 0.6391 - val_accuracy: 0.8569
# Epoch 53/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 69ms/step - loss: 0.5147 - accuracy: 0.8949 - val_loss: 0.8188 - val_accuracy: 0.7970
# Epoch 54/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 108s 69ms/step - loss: 0.5165 - accuracy: 0.8939 - val_loss: 0.7406 - val_accuracy: 0.8261
# Epoch 55/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 108s 69ms/step - loss: 0.5165 - accuracy: 0.8938 - val_loss: 0.7511 - val_accuracy: 0.8299
# Epoch 56/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5144 - accuracy: 0.8936 - val_loss: 0.8619 - val_accuracy: 0.8007
# Epoch 57/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 105s 67ms/step - loss: 0.5142 - accuracy: 0.8949 - val_loss: 0.6783 - val_accuracy: 0.8413
# Epoch 58/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 105s 67ms/step - loss: 0.5136 - accuracy: 0.8944 - val_loss: 0.7537 - val_accuracy: 0.8306
# Epoch 59/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 104s 67ms/step - loss: 0.5118 - accuracy: 0.8941 - val_loss: 0.7256 - val_accuracy: 0.8350
# Epoch 60/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 105s 67ms/step - loss: 0.5106 - accuracy: 0.8951 - val_loss: 0.6994 - val_accuracy: 0.8444
# Epoch 61/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 104s 67ms/step - loss: 0.5146 - accuracy: 0.8933 - val_loss: 0.8643 - val_accuracy: 0.8032
# Epoch 62/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 69ms/step - loss: 0.5060 - accuracy: 0.8975 - val_loss: 0.7230 - val_accuracy: 0.8428
# Epoch 63/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5046 - accuracy: 0.8974 - val_loss: 0.6827 - val_accuracy: 0.8487
# Epoch 64/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5077 - accuracy: 0.8954 - val_loss: 0.9647 - val_accuracy: 0.7753
# Epoch 65/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 106s 68ms/step - loss: 0.5030 - accuracy: 0.8970 - val_loss: 0.7934 - val_accuracy: 0.8276
# Epoch 66/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5017 - accuracy: 0.8994 - val_loss: 0.7782 - val_accuracy: 0.8160
# Epoch 67/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 108s 69ms/step - loss: 0.5038 - accuracy: 0.8965 - val_loss: 1.0039 - val_accuracy: 0.7824
# Epoch 68/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 108s 69ms/step - loss: 0.5052 - accuracy: 0.8959 - val_loss: 0.6370 - val_accuracy: 0.8627
# Epoch 69/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5016 - accuracy: 0.8988 - val_loss: 0.7099 - val_accuracy: 0.8418
# Epoch 70/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5028 - accuracy: 0.8976 - val_loss: 0.7960 - val_accuracy: 0.8252
# Epoch 71/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.5018 - accuracy: 0.8980 - val_loss: 0.7970 - val_accuracy: 0.8162
# Epoch 72/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 110s 70ms/step - loss: 0.4981 - accuracy: 0.8994 - val_loss: 0.6684 - val_accuracy: 0.8497
# Epoch 73/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 109s 70ms/step - loss: 0.4984 - accuracy: 0.8987 - val_loss: 0.7004 - val_accuracy: 0.8472
# Epoch 74/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 109s 70ms/step - loss: 0.4908 - accuracy: 0.9020 - val_loss: 0.7736 - val_accuracy: 0.8281
# Epoch 75/75
# Learning rate:  0.001
# 1563/1563 [==============================] - 109s 70ms/step - loss: 0.4975 - accuracy: 0.8988 - val_loss: 0.7915 - val_accuracy: 0.8265

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 72s 7ms/step
# Test loss: 0.7914542401313782
# Test accuracy: 0.8264999985694885
